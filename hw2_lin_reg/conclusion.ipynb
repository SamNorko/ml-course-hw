# %% [markdown]
# ### Выводы по работе

# %% [markdown]
# В ходе выполнения дз было выполнено:
# * Решили несколько примеров матричного дифференцирования;
# * Реализовали методы расчета MSE, MAE (без смещения) и их производных. При реализации учли, что размерность целевого признака может быть больше 1;
# * Реализовали методы расчета L1, L2 регуляризации и их производных;
# * Проверили корректность наших методов на предложенных данных;
# * Используя вышеуказанные методы реализовали линейную регрессию с градиентным спуском, сравнили с реализацией sklearn;
# * Результаты оказались близкими, беря во внимание отсутсвие смещения в нашей реализации;
